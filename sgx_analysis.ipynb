# %%
# Import necessary python libraries
import pandas as pd
import re

# %%
# Read raw data file
sgx = pd.read_excel("data/raw_sgx_data.xlsx")
sgx
# Out:
#                          Company name Latin alphabet  \
# 0                       WILMAR INTERNATIONAL LIMITED
# 1                                 OLAM GROUP LIMITED
# 2                                       FLEX LIMITED
# 3                       JARDINE CYCLE & CARRIAGE LTD
# 4            CHINA AVIATION OIL (SINGAPORE) CORP LTD
# ..                                               ...
# 600  PRINCIPAL S&P ETHICAL ASIA PACIFIC DIVIDEND ETF
# 601                       GLOBAL INVESTMENTS LIMITED
# 602                             I M QUARRIES LIMITED
# 603                     ABF PAN ASIA BOND INDEX FUND
# 604                                       YANGI FUND
#
#      NACE Rev. 2, core code (4 digits) Consolidation code  \
# 0                               1041.0                 C1
# 1                                  NaN                 C1
# 2                               2612.0                 C1
# 3                               4519.0                 C1
# 4                               4671.0                 C1
# ..                                 ...                ...
# 600                             6430.0                 NF
# 601                             6619.0                 C1
# 602                             8552.0                 C1
# 603                                NaN                 NF
# 604                             6420.0                 NF
#
#     Total current assets\nUSD 2023 Total current assets\nUSD 2022  \
# 0                      34373692000                    32632410000
# 1               17225670747.034698               15858883280.3866
# 2                             n.a.                    16021000000
# 3                      11564100000                    12131100000
# 4                             n.a.                     1205905000
# ..                             ...                            ...
# 600                           n.a.                           n.a.
# 601                76748826.021373                74323216.914833
# 602                           n.a.                              0
# 603                           n.a.                           n.a.
# 604                           n.a.                           n.a.
#
#     Total current assets\nUSD 2021 Total current assets\nUSD 2020  \
# 0                      31814998000                    27923570000
# 1                             n.a.                           n.a.
# 2                      14337000000                    11363000000
# 3                      11813500000                    10056700000
# 4                       1227737000                     1567111000
# ..                             ...                            ...
# 600                           n.a.                           n.a.
# 601                73032480.209112                74967855.558395
# 602                  480271.908641                  482482.197881
# 603                           n.a.                           n.a.
# 604                           n.a.                           n.a.
#
#     Total current assets\nUSD 2019 Total current assets\nUSD 2018  \
# 0                      25583701000                    26290404000
# 1                             n.a.                           n.a.
# 2                       9086270000                     9103432000
# 3                      10274500000                    10107700000
# 4                       1480610000                     1330707000
# ..                             ...                            ...
# 600                           n.a.                           n.a.
# 601                92773161.569118                75400059.378862
# 602                  466764.930487                  553875.669301
# 603                           n.a.                           n.a.
# 604                           n.a.                           n.a.
#
#     Total current assets\nUSD 2017  ...  \
# 0                      22579397000  ...
# 1                             n.a.  ...
# 2                       9170414000  ...
# 3                       9833700000  ...
# 4                       1575915000  ...
# ..                             ...  ...
# 600                           n.a.  ...
# 601                99939396.802247  ...
# 602                  791339.493155  ...
# 603                           n.a.  ...
# 604                           n.a.  ...
#
#     Cash & Cash Equivalents at the End of Period\nUSD 2013  \
# 0                                           2237232000
# 1                                                 n.a.
# 2                                           1593728000
# 3                                           1601000000
# 4                                             56299000
# ..                                                 ...
# 600                                               n.a.
# 601                                    16079981.269956
# 602                                                  0
# 603                                               n.a.
# 604                                               n.a.
#
#     Cash & Cash Equivalents at the End of Period\nUSD 2012  \
# 0                                           1528453000
# 1                                                 n.a.
# 2                                           1587087000
# 3                                           1201000000
# 4                                             81144000
# ..                                                 ...
# 600                                               n.a.
# 601                                     20031057.97267
# 602                                                  0
# 603                                               n.a.
# 604                                               n.a.
#
#     Cash & Cash Equivalents at the End of Period\nUSD 2011  \
# 0                                           1279658000
# 1                                                 n.a.
# 2                                           1518329000
# 3                                           1510200000
# 4                                             88065000
# ..                                                 ...
# 600                                               n.a.
# 601                                    32417927.886844
# 602                                      407773.454666
# 603                                               n.a.
# 604                                               n.a.
#
#     Cash & Cash Equivalents at the End of Period\nUSD 2010  \
# 0                                            400475000
# 1                                                 n.a.
# 2                                           1748471000
# 3                                            847800000
# 4                                             57988000
# ..                                                 ...
# 600                                               n.a.
# 601                                    15643633.756697
# 602                                               n.a.
# 603                                               n.a.
# 604                                               n.a.
#
#     Cash & Cash Equivalents at the End of Period\nUSD 2009  \
# 0                                            392263000
# 1                                                 n.a.
# 2                                           1927556000
# 3                                            962100000
# 4                                            182192000
# ..                                                 ...
# 600                                               n.a.
# 601                                    19594556.260526
# 602                                               n.a.
# 603                                               n.a.
# 604                                               n.a.
#
#     Cash & Cash Equivalents at the End of Period\nUSD 2008  \
# 0                                           1103696000
# 1                                                 n.a.
# 2                                           1821886000
# 3                                            839100000
# 4                                            153102000
# ..                                                 ...
# 600                                               n.a.
# 601                                    55742080.205917
# 602                                               n.a.
# 603                                               n.a.
# 604                                               n.a.
#
#     Cash & Cash Equivalents at the End of Period\nUSD 2007  \
# 0                                            444886000
# 1                                                 n.a.
# 2                                           1719948000
# 3                                            672100000
# 4                                            300472000
# ..                                                 ...
# 600                                               n.a.
# 601                                    87753951.332152
# 602                                               n.a.
# 603                                               n.a.
# 604                                               n.a.
#
#     Cash & Cash Equivalents at the End of Period\nUSD 2006  \
# 0                                            -94081000
# 1                                                 n.a.
# 2                                            714525000
# 3                                            551900000
# 4                                             85376000
# ..                                                 ...
# 600                                               n.a.
# 601                                    42342240.832508
# 602                                               n.a.
# 603                                               n.a.
# 604                                               n.a.
#
#     Cash & Cash Equivalents at the End of Period\nUSD 2005  \
# 0                                           -101230000
# 1                                                 n.a.
# 2                                            942859000
# 3                                            491000000
# 4                                      28657613.694668
# ..                                                 ...
# 600                                               n.a.
# 601                                               n.a.
# 602                                               n.a.
# 603                                               n.a.
# 604                                               n.a.
#
#     Cash & Cash Equivalents at the End of Period\nUSD 2004
# 0                                       3603868.301392
# 1                                                 n.a.
# 2                                            869258000
# 3                                            177000000
# 4                                       2484392.227471
# ..                                                 ...
# 600                                               n.a.
# 601                                               n.a.
# 602                                               n.a.
# 603                                               n.a.
# 604                                               n.a.
#
# [605 rows x 3043 columns]

# %%
# Removing "\nth" pattern and ".1" pattern (for duplicated column names) from the column names
sgx.columns = pd.Index([re.sub(pattern= "\.\d?$", repl= "", string= 
                               re.sub(pattern= " ?\n(th)? ?", repl= " ", string= col)) for col in sgx.columns])

sgx = sgx.loc[:, ~sgx.columns.duplicated()]

# %%
# Lengthening dataframe using columns with time periods

id_vars = ['Company name Latin alphabet', 'NACE Rev. 2, core code (4 digits)', 'Consolidation code']

melted_sgx = pd.melt(sgx, id_vars= id_vars)

melted_sgx["year"] = melted_sgx["variable"].str.extract(r"(\d{4})$")[0]
melted_sgx["variable"] = melted_sgx["variable"].str.replace("\s+\d{4}$|USD", "", regex= True)

melted_sgx
# Out:
#                              Company name Latin alphabet  \
# 0                           WILMAR INTERNATIONAL LIMITED
# 1                                     OLAM GROUP LIMITED
# 2                                           FLEX LIMITED
# 3                           JARDINE CYCLE & CARRIAGE LTD
# 4                CHINA AVIATION OIL (SINGAPORE) CORP LTD
# ...                                                  ...
# 1827095  PRINCIPAL S&P ETHICAL ASIA PACIFIC DIVIDEND ETF
# 1827096                       GLOBAL INVESTMENTS LIMITED
# 1827097                             I M QUARRIES LIMITED
# 1827098                     ABF PAN ASIA BOND INDEX FUND
# 1827099                                       YANGI FUND
#
#          NACE Rev. 2, core code (4 digits) Consolidation code  \
# 0                                   1041.0                 C1
# 1                                      NaN                 C1
# 2                                   2612.0                 C1
# 3                                   4519.0                 C1
# 4                                   4671.0                 C1
# ...                                    ...                ...
# 1827095                             6430.0                 NF
# 1827096                             6619.0                 C1
# 1827097                             8552.0                 C1
# 1827098                                NaN                 NF
# 1827099                             6420.0                 NF
#
#                                               variable               value  \
# 0                                Total current assets          34373692000
# 1                                Total current assets   17225670747.034698
# 2                                Total current assets                 n.a.
# 3                                Total current assets          11564100000
# 4                                Total current assets                 n.a.
# ...                                                ...                 ...
# 1827095  Cash & Cash Equivalents at the End of Period                 n.a.
# 1827096  Cash & Cash Equivalents at the End of Period                 n.a.
# 1827097  Cash & Cash Equivalents at the End of Period                 n.a.
# 1827098  Cash & Cash Equivalents at the End of Period                 n.a.
# 1827099  Cash & Cash Equivalents at the End of Period                 n.a.
#
#          year
# 0        2023
# 1        2023
# 2        2023
# 3        2023
# 4        2023
# ...       ...
# 1827095  2004
# 1827096  2004
# 1827097  2004
# 1827098  2004
# 1827099  2004
#
# [1827100 rows x 6 columns]

# %%
pivoted_sgx = melted_sgx.pivot(index= id_vars + ["year"], columns= "variable",values= "value").reset_index().rename_axis(None, axis=1)
pivoted_sgx
# Out:
#             Company name Latin alphabet  NACE Rev. 2, core code (4 digits)  \
# 0                      5E RESOURCES LTD                             3900.0
# 1                      5E RESOURCES LTD                             3900.0
# 2                      5E RESOURCES LTD                             3900.0
# 3                      5E RESOURCES LTD                             3900.0
# 4                      5E RESOURCES LTD                             3900.0
# ...                                 ...                                ...
# 12095  ZHONGXIN FRUIT AND JUICE LIMITED                             1039.0
# 12096  ZHONGXIN FRUIT AND JUICE LIMITED                             1039.0
# 12097  ZHONGXIN FRUIT AND JUICE LIMITED                             1039.0
# 12098  ZHONGXIN FRUIT AND JUICE LIMITED                             1039.0
# 12099  ZHONGXIN FRUIT AND JUICE LIMITED                             1039.0
#
#       Consolidation code  year Accounts receivable   \
# 0                     C1  2004                 n.a.
# 1                     C1  2005                 n.a.
# 2                     C1  2006                 n.a.
# 3                     C1  2007                 n.a.
# 4                     C1  2008                 n.a.
# ...                  ...   ...                  ...
# 12095                 C1  2019                 n.a.
# 12096                 C1  2020                 n.a.
# 12097                 C1  2021          1857.901454
# 12098                 C1  2022      14098553.819001
# 12099                 C1  2023      12662561.843425
#
#       Accumulated depreciation - No breakdown   \
# 0                                         n.a.
# 1                                         n.a.
# 2                                         n.a.
# 3                                         n.a.
# 4                                         n.a.
# ...                                        ...
# 12095                                     n.a.
# 12096                                     n.a.
# 12097                                     n.a.
# 12098                                     n.a.
# 12099                                     n.a.
#
#       Accumulated depreciation on buildings   \
# 0                                       n.a.
# 1                                       n.a.
# 2                                       n.a.
# 3                                       n.a.
# 4                                       n.a.
# ...                                      ...
# 12095                        -3855653.379798
# 12096                        -4074503.943145
# 12097                        -4785334.844947
# 12098                        -4931439.227164
# 12099                        -4837678.765491
#
#       Accumulated depreciation on land   \
# 0                                  n.a.
# 1                                  n.a.
# 2                                  n.a.
# 3                                  n.a.
# 4                                  n.a.
# ...                                 ...
# 12095                              n.a.
# 12096                              n.a.
# 12097                              n.a.
# 12098                              n.a.
# 12099                              n.a.
#
#       Accumulated depreciation on leased assets   \
# 0                                           n.a.
# 1                                           n.a.
# 2                                           n.a.
# 3                                           n.a.
# 4                                           n.a.
# ...                                          ...
# 12095                                       n.a.
# 12096                             -335875.285983
# 12097                             -396507.135302
# 12098                             -410318.447888
# 12099                             -404115.522534
#
#       Accumulated depreciation on other property, plant & equipment   ...  \
# 0                                                   n.a.              ...
# 1                                                   n.a.              ...
# 2                                                   n.a.              ...
# 3                                                   n.a.              ...
# 4                                                   n.a.              ...
# ...                                                  ...              ...
# 12095                                     -432224.627256              ...
# 12096                                     -356107.032359              ...
# 12097                                     -451624.878436              ...
# 12098                                     -498297.175884              ...
# 12099                                     -515543.422237              ...
#
#       Total other current liabilities  Total other non-current assets   \
# 0                                 n.a.                            n.a.
# 1                                 n.a.                            n.a.
# 2                                 n.a.                            n.a.
# 3                                 n.a.                            n.a.
# 4                                 n.a.                            n.a.
# ...                                ...                             ...
# 12095                   9330692.829371                   924302.462667
# 12096                  10067203.811884                  1455978.335321
# 12097                   15766771.03889                  1627986.149043
# 12098                   7944075.839996                  2081466.170847
# 12099                   8433673.333421                  1698827.830583
#
#       Total other non-current liabilities  Total others current assets   \
# 0                                     n.a.                         n.a.
# 1                                     n.a.                         n.a.
# 2                                     n.a.                         n.a.
# 3                                     n.a.                         n.a.
# 4                                     n.a.                         n.a.
# ...                                    ...                          ...
# 12095                         32620.726585               9413118.415296
# 12096                         30842.802167              16384177.545607
# 12097                         32822.925687              12392047.872871
# 12098                         31666.367292                796439.011335
# 12099                         28373.482496               5692602.094859
#
#       Total shareholders' equity  Trade creditors  Transportation equipment   \
# 0                            n.a.             n.a.                      n.a.
# 1                            n.a.             n.a.                      n.a.
# 2                            n.a.             n.a.                      n.a.
# 3                            n.a.             n.a.                      n.a.
# 4                            n.a.             n.a.                      n.a.
# ...                           ...              ...                       ...
# 12095             11931322.005093    192229.281664             317178.314745
# 12096             12065053.396285     329933.09474             345071.534336
# 12097             12603693.813503    230534.605414             395887.834817
# 12098             19238662.457049    252135.981083              381938.21305
# 12099             18562042.436868    316102.632657              352189.29486
#
#       Treasury shares  Unusual & exceptional income (expenses)   \
# 0                 n.a.                                     n.a.
# 1                 n.a.                                     n.a.
# 2                 n.a.                                     n.a.
# 3                 n.a.                                     n.a.
# 4                 n.a.                                     n.a.
# ...                ...                                      ...
# 12095             n.a.                              2475.680143
# 12096             n.a.                                     n.a.
# 12097             n.a.                                     n.a.
# 12098             n.a.                                     n.a.
# 12099             n.a.                              4407.531261
#
#       Work in progress
# 0                  n.a.
# 1                  n.a.
# 2                  n.a.
# 3                  n.a.
# 4                  n.a.
# ...                 ...
# 12095     466301.636279
# 12096     472404.203832
# 12097     409976.920843
# 12098     432574.526787
# 12099     370094.890609
#
# [12100 rows x 155 columns]

# %%
pivoted_sgx = pivoted_sgx.drop(columns= [col for col in pivoted_sgx.columns if pivoted_sgx[col].eq("n.a.").all()])

# %%
pivoted_sgx.to_csv("Data/sgx_data.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 pivoted_sgx.to_csv("Data/sgx_data.csv")
#
# NameError: name 'pivoted_sgx' is not defined

# %% [markdown]
# ## Filter out usable fields

# %%
sgx = pd.read_csv("Data/sgx_data.csv")
sgx
# Out:
#        Unnamed: 0       Company name Latin alphabet  \
# 0               0                  5E RESOURCES LTD
# 1               1                  5E RESOURCES LTD
# 2               2                  5E RESOURCES LTD
# 3               3                  5E RESOURCES LTD
# 4               4                  5E RESOURCES LTD
# ...           ...                               ...
# 12095       12095  ZHONGXIN FRUIT AND JUICE LIMITED
# 12096       12096  ZHONGXIN FRUIT AND JUICE LIMITED
# 12097       12097  ZHONGXIN FRUIT AND JUICE LIMITED
# 12098       12098  ZHONGXIN FRUIT AND JUICE LIMITED
# 12099       12099  ZHONGXIN FRUIT AND JUICE LIMITED
#
#        NACE Rev. 2, core code (4 digits) Consolidation code  year  \
# 0                                 3900.0                 C1  2004
# 1                                 3900.0                 C1  2005
# 2                                 3900.0                 C1  2006
# 3                                 3900.0                 C1  2007
# 4                                 3900.0                 C1  2008
# ...                                  ...                ...   ...
# 12095                             1039.0                 C1  2019
# 12096                             1039.0                 C1  2020
# 12097                             1039.0                 C1  2021
# 12098                             1039.0                 C1  2022
# 12099                             1039.0                 C1  2023
#
#       Accounts receivable  Accumulated depreciation - No breakdown   \
# 0                     n.a.                                     n.a.
# 1                     n.a.                                     n.a.
# 2                     n.a.                                     n.a.
# 3                     n.a.                                     n.a.
# 4                     n.a.                                     n.a.
# ...                    ...                                      ...
# 12095                 n.a.                                     n.a.
# 12096                 n.a.                                     n.a.
# 12097     1857.90145397186                                     n.a.
# 12098     14098553.8190007                                     n.a.
# 12099      12662561.843425                                     n.a.
#
#       Accumulated depreciation on buildings   \
# 0                                       n.a.
# 1                                       n.a.
# 2                                       n.a.
# 3                                       n.a.
# 4                                       n.a.
# ...                                      ...
# 12095                      -3855653.37979794
# 12096                      -4074503.94314528
# 12097                      -4785334.84494686
# 12098                      -4931439.22716379
# 12099                      -4837678.76549065
#
#       Accumulated depreciation on land   \
# 0                                  n.a.
# 1                                  n.a.
# 2                                  n.a.
# 3                                  n.a.
# 4                                  n.a.
# ...                                 ...
# 12095                              n.a.
# 12096                              n.a.
# 12097                              n.a.
# 12098                              n.a.
# 12099                              n.a.
#
#       Accumulated depreciation on leased assets   ...  \
# 0                                           n.a.  ...
# 1                                           n.a.  ...
# 2                                           n.a.  ...
# 3                                           n.a.  ...
# 4                                           n.a.  ...
# ...                                          ...  ...
# 12095                                       n.a.  ...
# 12096                          -335875.285983086  ...
# 12097                          -396507.135301828  ...
# 12098                          -410318.447887897  ...
# 12099                          -404115.522533655  ...
#
#       Total other current liabilities  Total other non-current assets   \
# 0                                 n.a.                            n.a.
# 1                                 n.a.                            n.a.
# 2                                 n.a.                            n.a.
# 3                                 n.a.                            n.a.
# 4                                 n.a.                            n.a.
# ...                                ...                             ...
# 12095                  9330692.8293705                924302.462667227
# 12096                 10067203.8118839                1455978.33532095
# 12097                 15766771.0388899                1627986.14904284
# 12098                 7944075.83999634                2081466.17084742
# 12099                 8433673.33342135                1698827.83058286
#
#       Total other non-current liabilities  Total others current assets   \
# 0                                     n.a.                         n.a.
# 1                                     n.a.                         n.a.
# 2                                     n.a.                         n.a.
# 3                                     n.a.                         n.a.
# 4                                     n.a.                         n.a.
# ...                                    ...                          ...
# 12095                     32620.7265853882             9413118.41529608
# 12096                     30842.8021669388             16384177.5456071
# 12097                     32822.9256868362             12392047.8728712
# 12098                     31666.3672924042             796439.011335373
# 12099                     28373.4824955463             5692602.09485888
#
#       Total shareholders' equity   Trade creditors  Transportation equipment   \
# 0                            n.a.              n.a.                      n.a.
# 1                            n.a.              n.a.                      n.a.
# 2                            n.a.              n.a.                      n.a.
# 3                            n.a.              n.a.                      n.a.
# 4                            n.a.              n.a.                      n.a.
# ...                           ...               ...                       ...
# 12095            11931322.0050931  192229.281663895          317178.314745426
# 12096            12065053.3962846  329933.094739914          345071.534335613
# 12097            12603693.8135028  230534.605413675          395887.834817171
# 12098            19238662.4570489  252135.981082916          381938.213050365
# 12099             18562042.436868  316102.632656693          352189.294859767
#
#       Treasury shares  Unusual & exceptional income (expenses)   \
# 0                 n.a.                                     n.a.
# 1                 n.a.                                     n.a.
# 2                 n.a.                                     n.a.
# 3                 n.a.                                     n.a.
# 4                 n.a.                                     n.a.
# ...                ...                                      ...
# 12095             n.a.                         2475.68014264107
# 12096             n.a.                                     n.a.
# 12097             n.a.                                     n.a.
# 12098             n.a.                                     n.a.
# 12099             n.a.                         4407.53126144409
#
#       Work in progress
# 0                  n.a.
# 1                  n.a.
# 2                  n.a.
# 3                  n.a.
# 4                  n.a.
# ...                 ...
# 12095  466301.636278629
# 12096   472404.20383215
# 12097  409976.920843124
# 12098  432574.526786804
# 12099  370094.890609384
#
# [12100 rows x 150 columns]

# %%
useful_fields = ['Company name Latin alphabet', 'NACE Rev. 2, core code (4 digits)', 'Consolidation code', 'year',
                 'Total shareholders\' equity ', 'Total liabilities ', 'Total current assets ', 'Net Cash from Operating Activities ',
                 'Net Cash from Financing Activities ', 'Net Cash from Investing Activities ', 'Total current liabilities ',
                 'Depreciation, Depletion & Amortization ', 'EBITDA ', 'Total depreciation, amortization & depletion ',
                 'Net property, plant & equipment ', 'Total long-term interest-bearing debt ', 'Net debt ', 'Net Income/Starting Line ',
                 'Net profit ', 'Earnings before interest & tax (EBIT) ', 'Increase/Decrease in Long Term Borrowings ', 'Increase/Decrease in Short Term Borrowings ',
                 'Loans & Borrowings ', 'Total assets ', 'Income tax expense ', 'Intangible assets ']
sgx = sgx[useful_fields]

# %%
colname_mapping = {
    'Company name Latin alphabet' : 'Company',
    'NACE Rev. 2, core code (4 digits)' : 'NACE',
    'year' : 'Year',
    'Total shareholders\' equity ' : 'TE',
    'Total liabilities ' : 'TL',
    'Total current assets ' : 'CA',
    'Net Cash from Operating Activities ' : 'CFO',
    'Net Cash from Financing Activities ' : 'CFF',
    'Net Cash from Investing Activities ' : 'CFI',
    'Total current liabilities ' : 'CL',
    'Depreciation, Depletion & Amortization ' : 'DA',
    'EBITDA ' : 'EBIDTA',
    'Total depreciation, amortization & depletion ' : 'TDA', # need to check if this duplicates with DA
    'Net property, plant & equipment ' : 'FA', # fixed assets
    'Total long-term interest-bearing debt ' : 'LTD',
    'Net debt ' : 'ND',
    'Net Income/Starting Line ' : 'NI', # net income from cashflow statement
    'Net profit ' : 'NP', # need to check if this duplicates with NI
    'Earnings before interest & tax (EBIT) ' : 'EBIT',
    'Increase/Decrease in Long Term Borrowings ' : 'DeltaLTB',
    'Increase/Decrease in Short Term Borrowings ' : 'DeltaSTB',
    'Loans & Borrowings ' : 'LB',
    'Total assets ' : 'TA',
    'Income tax expense ' : 'ITE', # can be used to calculate tax coverage & interest expense with EBIT
    'Intangible assets ' : 'IA'
}

sgx = sgx.rename(columns = colname_mapping)

# %%
sgx.to_csv("Data/filteredSGX.csv")

# %%
sgx.replace('n.a.', pd.NA, inplace = True)
sgx.dropna(inplace = True)
# Out:
#                            Company    NACE Consolidation code  Year  \
# 34             8I HOLDINGS LIMITED  7022.0                 C1  2018
# 62       A SONIC AEROSPACE LIMITED  2611.0                 C1  2006
# 63       A SONIC AEROSPACE LIMITED  2611.0                 C1  2007
# 83            A-SMART HOLDINGS LTD  1812.0                 C1  2007
# 84            A-SMART HOLDINGS LTD  1812.0                 C1  2008
# ...                            ...     ...                ...   ...
# 11976                 YKGI LIMITED  5610.0                 C1  2020
# 11990  YOMA STRATEGIC HOLDINGS LTD  5510.0                 C1  2014
# 11991  YOMA STRATEGIC HOLDINGS LTD  5510.0                 C1  2015
# 11997  YOMA STRATEGIC HOLDINGS LTD  5510.0                 C1  2021
# 12007     YONGMAO HOLDINGS LIMITED  2892.0                 C1  2011
#
#                      TE                TL                CA  \
# 34     23843204.4112086  7620768.69624853  27840549.4546294
# 62             61099000          63182000          83867000
# 63             49096000          59414000          89921000
# 83     67627172.5063324  12083084.8755836   17888469.353199
# 84     81143610.4922295  23332846.2207317  37105148.2754946
# ...                 ...               ...               ...
# 11976   6221919.7883606  16414038.5761261  11370547.0676422
# 11990  531922253.856957   74034869.273603  248833993.303776
# 11991  545041056.325734  156911399.385154  268142984.110832
# 11997         681403000         547998000         553299000
# 12007  73440413.8748646  126774541.237637  129557535.357445
#
#                      CFO                CFF                CFI  ...  \
# 34     -4644885.43975353   252230.997204781     3112324.000597  ...
# 62               3414000            4688000            9481000  ...
# 63               5333000           -9831000            5590000  ...
# 83     -723688.539028168  -2028180.12857437  -2197525.89273453  ...
# 84      92132.2038173676   5369260.10024548   3558057.96647072  ...
# ...                  ...                ...                ...  ...
# 11976   7969140.15197754  -4386960.22033691  -1199606.70852661  ...
# 11990  -14825281.1554074   195450049.796999  -178478019.692004  ...
# 11991   10088816.1253333   44408998.3373284  -58584854.4923067  ...
# 11997            4194000           32553000          -40473000  ...
